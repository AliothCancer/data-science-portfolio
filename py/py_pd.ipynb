# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../house-prices-advanced-regression-techniques/test.csv')
corr = df.select_dtypes(float).corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr.
# Out:
#        LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# count    11.000000   11.000000   11.000000   11.000000  11.000000
# mean      0.253579    0.301941    0.285423    0.100239   0.072227
# std       0.280569    0.272846    0.377566    0.319210   0.403067
# min      -0.042779    0.003992   -0.459581   -0.265183  -0.459581
# 25%       0.087050    0.131471    0.146796   -0.022870  -0.191435
# 50%       0.204621    0.257439    0.285959    0.037546   0.092031
# 75%       0.326088    0.366835    0.446855    0.099904   0.150125
# max       1.000000    1.000000    1.000000    1.000000   1.000000
#
#        TotalBsmtSF  BsmtFullBath  BsmtHalfBath  GarageYrBlt  GarageCars  \
# count    11.000000     11.000000     11.000000    11.000000   11.000000
# mean      0.404554      0.226783      0.075125     0.301349    0.382120
# std       0.254804      0.360103      0.316862     0.311429    0.334664
# min       0.024722     -0.374659     -0.150071    -0.051545   -0.044934
# 25%       0.329741      0.146907     -0.043856     0.117658    0.168450
# 50%       0.409023      0.189895     -0.018561     0.232798    0.336373
# 75%       0.463479      0.270975      0.056847     0.460259    0.514025
# max       1.000000      1.000000      1.000000     1.000000    1.000000
#
#        GarageArea
# count   11.000000
# mean     0.394953
# std      0.326989
# min     -0.018561
# 25%      0.167873
# 50%      0.375182
# 75%      0.516835
# max      1.000000
