# %%
# %%sh
# which python
# python -V
# pwd
# Out:
# /home/giulio/Scrivania/rust_data_science_env/py/.venv/bin/python
# Python 3.13.7
# /home/giulio/Scrivania/rust_data_science_env/py

# %%
import polars as pl
from polars.selectors import by_dtype

# %%
df = pl.read_csv("../house-prices-advanced-regression-techniques/train.csv",null_values=['NA'])
df
# Out:
# shape: (1_460, 81)
# ┌──────┬────────────┬──────────┬─────────────┬───┬────────┬──────────┬───────────────┬───────────┐
# │ Id   ┆ MSSubClass ┆ MSZoning ┆ LotFrontage ┆ … ┆ YrSold ┆ SaleType ┆ SaleCondition ┆ SalePrice │
# │ ---  ┆ ---        ┆ ---      ┆ ---         ┆   ┆ ---    ┆ ---      ┆ ---           ┆ ---       │
# │ i64  ┆ i64        ┆ str      ┆ i64         ┆   ┆ i64    ┆ str      ┆ str           ┆ i64       │
# ╞══════╪════════════╪══════════╪═════════════╪═══╪════════╪══════════╪═══════════════╪═══════════╡
# │ 1    ┆ 60         ┆ RL       ┆ 65          ┆ … ┆ 2008   ┆ WD       ┆ Normal        ┆ 208500    │
# │ 2    ┆ 20         ┆ RL       ┆ 80          ┆ … ┆ 2007   ┆ WD       ┆ Normal        ┆ 181500    │
# │ 3    ┆ 60         ┆ RL       ┆ 68          ┆ … ┆ 2008   ┆ WD       ┆ Normal        ┆ 223500    │
# │ 4    ┆ 70         ┆ RL       ┆ 60          ┆ … ┆ 2006   ┆ WD       ┆ Abnorml       ┆ 140000    │
# ...

# %%
(
    df.select(by_dtype(pl.String))
    .select(pl.col(['Street', 'LotShape']))
    # .write_csv("only_str.csv")
)

# %%
(
    df.select(pl.exclude('Id')).select(by_dtype(pl.Int64)).corr()
    .select(
        pl.col('LotArea').max()
    )
)
# Out:
# shape: (1, 1)
# ┌─────────┐
# │ LotArea │
# │ ---     │
# │ f64     │
# ╞═════════╡
# │ 1.0     │
# └─────────┘
