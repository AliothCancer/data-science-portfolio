// %%
:dep polars

// %%
use polars::prelude::*;

// %%
let path = "../house-prices-advanced-regression-techniques/train.csv";
let df =
// Out:
// [E0433] Error: failed to resolve: use of undeclared type `LazyCsvReader`
//    ╭─[command_4:1:1]
//    │
//  2 │ let df = LazyCsvReader::new(PlPath::new(path));
//    │          ──────┬──────
//    │                ╰──────── use of undeclared type `LazyCsvReader`
//    │                │
//    │                ╰──────── help: a struct with a similar name exists: `CsvReader`
// ───╯
